# %%
# Out:
# /home/matthieu/anaconda3/envs/mpa_env/lib/python3.10/site-packages/geopandas/plotting.py:642: FutureWarning: 'colormap' is deprecated, please use 'cmap' instead (for consistency with matplotlib)
#   warnings.warn(
# <Axes: >

# %%
import seaborn as sns
sns.catplot(data=points, x="cluster", y='year', palette="ch:.25").set(title='Cluster distribution per year over Africa')
# Out:
# /tmp/ipykernel_4629/2387803664.py:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.catplot(data=points, x="cluster", y='year', palette="ch:.25").set(title='Cluster distribution per year over Africa')
