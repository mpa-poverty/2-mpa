# %%
import glob
import os 
import rasterio as rio
import pandas as pd
import geopandas as gpd
import rioxarray as rxr
import xarray as xr 
from shapely import Point, Polygon
import matplotlib.pyplot as plt

# %%
PATH=os.path.join('..','data','landsat_tiles','')
CSV_PATH=os.path.join('..','data','wealth_index.csv')

# %%
# GLOB FILES
files=dict()
csv=pd.read_csv(CSV_PATH)
for year in csv.year.unique():
    if int(year) < 2016:
        continue
    files[year]=dict()
    for country in csv.country.unique():
        files[year][country]=[]
        country_cap=country.title()
        files[year][country]=glob.glob(os.path.join(PATH,str(country_cap)+"_"+str(year)+"*.tif"))

files
# Out:
# {2017: {'angola': [],
#   'benin': ['../data/landsat_tiles/Benin_2017-0000017920-0000000000.tif'],
#   'burkina_faso': [],
#   'cameroon': [],
#   'cote_d_ivoire': [],
#   'democratic_republic_of_congo': [],
#   'ethiopia': [],
#   'ghana': [],
#   'guinea': [],
#   'kenya': [],
#   'lesotho': [],
#   'madagascar': [],
#   'malawi': ['../data/landsat_tiles/Malawi_2017-0000026880-0000000000.tif',
#    '../data/landsat_tiles/Malawi_2017-0000017920-0000000000.tif',
#    '../data/landsat_tiles/Malawi_2017-0000000000-0000000000.tif'],
#   'mali': [],
#   'mozambique': [],
#   'nigeria': [],
#   'rwanda': [],
#   'senegal': [],
#   'sierra_leone': [],
#   'tanzania': ['../data/landsat_tiles/Tanzania_2017-0000000000-0000035840.tif',
#    '../data/landsat_tiles/Tanzania_2017-0000035840-0000035840.tif',
#    '../data/landsat_tiles/Tanzania_2017-0000026880-0000035840.tif',
#    '../data/landsat_tiles/Tanzania_2017-0000000000-0000017920.tif',
#    '../data/landsat_tiles/Tanzania_2017-0000017920-0000035840.tif',
#    '../data/landsat_tiles/Tanzania_2017-0000008960-0000035840.tif',
#    '../data/landsat_tiles/Tanzania_2017-0000017920-0000026880.tif',
#    '../data/landsat_tiles/Tanzania_2017-0000026880-0000000000.tif',
#    '../data/landsat_tiles/Tanzania_2017-0000026880-0000017920.tif',
#    '../data/landsat_tiles/Tanzania_2017-0000026880-0000026880.tif',
#    '../data/landsat_tiles/Tanzania_2017-0000008960-0000000000.tif',
#    '../data/landsat_tiles/Tanzania_2017-0000035840-0000026880.tif'],
#   'togo': [],
#   'uganda': [],
#   'zambia': [],
#   'zimbabwe': []},
#  2018: {'angola': [],
#   'benin': [],
#   'burkina_faso': [],
#   'cameroon': ['../data/landsat_tiles/Cameroon_2018-0000026880-0000026880.tif',
#    '../data/landsat_tiles/Cameroon_2018-0000008960-0000000000.tif',
#    '../data/landsat_tiles/Cameroon_2018-0000026880-0000017920.tif',
#    '../data/landsat_tiles/Cameroon_2018-0000008960-0000017920.tif',
#    '../data/landsat_tiles/Cameroon_2018-0000000000-0000008960.tif',
#    '../data/landsat_tiles/Cameroon_2018-0000035840-0000026880.tif',
#    '../data/landsat_tiles/Cameroon_2018-0000000000-0000000000.tif',
#    '../data/landsat_tiles/Cameroon_2018-0000000000-0000026880.tif'],
#   'cote_d_ivoire': [],
#   'democratic_republic_of_congo': [],
#   'ethiopia': [],
#   'ghana': [],
#   'guinea': ['../data/landsat_tiles/Guinea_2018-0000017920-0000000000.tif',
#    '../data/landsat_tiles/Guinea_2018-0000000000-0000008960.tif',
#    '../data/landsat_tiles/Guinea_2018-0000008960-0000026880.tif'],
#   'kenya': [],
#   'lesotho': [],
#   'madagascar': [],
#   'malawi': [],
#   'mali': [],
#   'mozambique': ['../data/landsat_tiles/Mozambique_2018-0000000000-0000000000.tif',
#    '../data/landsat_tiles/Mozambique_2018-0000000000-0000017920.tif',
#    '../data/landsat_tiles/Mozambique_2018-0000000000-0000008960.tif'],
#   'nigeria': [],
#   'rwanda': [],
#   'senegal': [],
#   'sierra_leone': [],
#   'tanzania': [],
#   'togo': [],
#   'uganda': [],
#   'zambia': [],
#   'zimbabwe': []},
#  2016: {'angola': [],
#   'benin': [],
#   'burkina_faso': [],
#   'cameroon': [],
#   'cote_d_ivoire': [],
#   'democratic_republic_of_congo': [],
#   'ethiopia': [],
#   'ghana': [],
#   'guinea': [],
#   'kenya': [],
#   'lesotho': [],
#   'madagascar': [],
#   'malawi': [],
#   'mali': [],
#   'mozambique': [],
#   'nigeria': [],
#   'rwanda': [],
#   'senegal': [],
#   'sierra_leone': [],
#   'tanzania': [],
#   'togo': [],
#   'uganda': [],
#   'zambia': [],
#   'zimbabwe': []},
#  2019: {'angola': [],
#   'benin': [],
#   'burkina_faso': [],
#   'cameroon': [],
#   'cote_d_ivoire': [],
#   'democratic_republic_of_congo': [],
#   'ethiopia': [],
#   'ghana': [],
#   'guinea': [],
#   'kenya': [],
#   'lesotho': [],
#   'madagascar': [],
#   'malawi': [],
#   'mali': [],
#   'mozambique': [],
#   'nigeria': [],
#   'rwanda': [],
#   'senegal': [],
#   'sierra_leone': [],
#   'tanzania': [],
#   'togo': [],
#   'uganda': [],
#   'zambia': [],
#   'zimbabwe': []}}

# %%
# UPDATE POINT COORDINATES & CRS
                  
gdf = gpd.GeoDataFrame(csv, geometry=gpd.points_from_xy(csv.lon, csv.lon))
gdf.set_crs(epsg="4326", inplace=True)
gdf = gdf.to_crs('EPSG:3857')

gdf.head()
# Out:
#   country  year  month  day  cluster        lat        lon  households  \
# 0  angola  2011    NaN  NaN        1 -12.350257  13.534922          36
# 1  angola  2011    NaN  NaN        2 -12.360865  13.551494          32
# 2  angola  2011    NaN  NaN        3 -12.613421  13.413085          36
# 3  angola  2011    NaN  NaN        4 -12.581454  13.397711          35
# 4  angola  2011    NaN  NaN        5 -12.578135  13.418748          37
#
#    wealthpooled                         geometry
# 0      2.312757  POINT (1506700.586 1520912.661)
# 1      2.010293  POINT (1508545.372 1522810.211)
# 2      0.877744  POINT (1493137.790 1506965.991)
# 3      1.066994  POINT (1491426.344 1505206.609)
# 4      1.750153  POINT (1493768.184 1507614.069)

# %%
def open_tif(file):
    return rxr.open_rasterio(file, masked=True)

def get_bb_from_point(point, margin=3000):
    minx=point.x-margin
    miny=point.y-margin
    maxx=point.x+margin
    maxy=point.y+margin
    return Polygon([
        Point(minx, miny), 
        Point(maxx, miny), 
        Point(maxx, maxy), 
        Point(minx, maxy), 
        Point(minx, miny)
    ])

def clip_geometry(point, tif, margin=3000):
    try :
        tile = tif.rio.clip_box(
                minx=point.x-margin,
                miny=point.y-margin,
                maxx=point.x+margin,
                maxy=point.y+margin
            )
    except rxr.exceptions.NoDataInBounds:
        return None
    return tile

def write_tile(tile, name, path=os.path.join('..','data','landsat_tiles','')):
    tile.rio.to_raster(path+name+'.tif')
    return 

def add_roi_coords(gdf, margin=3000):
    gdf['roi'] = gdf['geometry'].map( lambda point: get_bb_from_point(point) )
    return gdf

def write_gdf(gdf, name, path=PATH):
    gdf.to_file(name+".geojson", driver="GeoJSON")

# %%
gdf = add_roi_coords(gdf)
gdf.head()
# Out:
#   country  year  month  day  cluster        lat        lon  households  \
# 0  angola  2011    NaN  NaN        1 -12.350257  13.534922          36
# 1  angola  2011    NaN  NaN        2 -12.360865  13.551494          32
# 2  angola  2011    NaN  NaN        3 -12.613421  13.413085          36
# 3  angola  2011    NaN  NaN        4 -12.581454  13.397711          35
# 4  angola  2011    NaN  NaN        5 -12.578135  13.418748          37
#
#    wealthpooled                         geometry  \
# 0      2.312757  POINT (1506700.586 1520912.661)
# 1      2.010293  POINT (1508545.372 1522810.211)
# 2      0.877744  POINT (1493137.790 1506965.991)
# 3      1.066994  POINT (1491426.344 1505206.609)
# 4      1.750153  POINT (1493768.184 1507614.069)
#
#                                                  roi
# 0  POLYGON ((1503700.586 1517912.661, 1509700.586...
# 1  POLYGON ((1505545.372 1519810.211, 1511545.372...
# 2  POLYGON ((1490137.790 1503965.991, 1496137.790...
# 3  POLYGON ((1488426.344 1502206.609, 1494426.344...
# 4  POLYGON ((1490768.184 1504614.069, 1496768.184...

# %%
# def plot_tile(tile, bands=[0,1,2]): # default bands: rgb
#     tile.plot.imshow()

 # cp -r landsat/*/*/*.tif landsat_tiles/

# %%
# LOOPING OVER OCCURENCES
for year in files:
    countries = files[year]
    for country in countries:
        occurences = gdf[gdf.year == year]
        occurences = occurences[occurences.country == country]
        for idx, row in occurences.iterrows():
            for file in countries[country]:
                tif = open_tif(file)
                tile = clip_geometry(row.geometry, tif)
                if tile is not None:
                    print(tile)
                    break
      
    
                # if tile is not None:
                #     print('ok')
                #     write_tile(
                #         tile=tile,
                #         name=str(row.geometry.x)+'_'+str(row.geometry.y)
                #     )
                #     if idx%25==0:
                #         plt.figure()
                #         tile.plot.imshow()
                #         plt.show()
# Out:
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.264e+06 1.264e+06 1.264e+06 ... 1.27e+06 1.27e+06
#   * y            (y) float64 1.278e+06 1.278e+06 ... 1.272e+06 1.272e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.283e+06 1.283e+06 ... 1.288e+06 1.289e+06
#   * y            (y) float64 1.297e+06 1.297e+06 ... 1.291e+06 1.291e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.127e+06 1.127e+06 ... 1.133e+06 1.133e+06
#   * y            (y) float64 1.139e+06 1.139e+06 ... 1.133e+06 1.133e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.12e+06 1.121e+06 ... 1.126e+06 1.126e+06
#   * y            (y) float64 1.132e+06 1.132e+06 ... 1.126e+06 1.126e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.081e+06 1.081e+06 ... 1.087e+06 1.087e+06
#   * y            (y) float64 1.092e+06 1.092e+06 ... 1.086e+06 1.086e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.239e+06 1.239e+06 ... 1.245e+06 1.245e+06
#   * y            (y) float64 1.253e+06 1.253e+06 ... 1.247e+06 1.247e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.363e+06 1.363e+06 ... 1.369e+06 1.369e+06
#   * y            (y) float64 1.38e+06 1.38e+06 1.38e+06 ... 1.374e+06 1.374e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.083e+06 1.083e+06 ... 1.089e+06 1.089e+06
#   * y            (y) float64 1.094e+06 1.094e+06 ... 1.088e+06 1.088e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.109e+06 1.109e+06 ... 1.115e+06 1.115e+06
#   * y            (y) float64 1.12e+06 1.12e+06 1.12e+06 ... 1.114e+06 1.114e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.279e+06 1.279e+06 ... 1.285e+06 1.285e+06
#   * y            (y) float64 1.293e+06 1.293e+06 ... 1.287e+06 1.287e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.131e+06 1.131e+06 ... 1.137e+06 1.137e+06
#   * y            (y) float64 1.143e+06 1.143e+06 ... 1.137e+06 1.137e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.048e+06 1.048e+06 ... 1.054e+06 1.054e+06
#   * y            (y) float64 1.059e+06 1.059e+06 ... 1.053e+06 1.053e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.047e+06 1.047e+06 ... 1.053e+06 1.053e+06
#   * y            (y) float64 1.058e+06 1.058e+06 ... 1.052e+06 1.052e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.289e+06 1.289e+06 ... 1.295e+06 1.295e+06
#   * y            (y) float64 1.304e+06 1.304e+06 ... 1.298e+06 1.298e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.183e+06 1.183e+06 ... 1.189e+06 1.189e+06
#   * y            (y) float64 1.196e+06 1.196e+06 1.195e+06 ... 1.19e+06 1.19e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.241e+06 1.241e+06 ... 1.247e+06 1.247e+06
#   * y            (y) float64 1.255e+06 1.255e+06 ... 1.249e+06 1.249e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.283e+06 1.283e+06 ... 1.289e+06 1.289e+06
#   * y            (y) float64 1.298e+06 1.298e+06 ... 1.292e+06 1.292e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.089e+06 1.089e+06 ... 1.095e+06 1.095e+06
#   * y            (y) float64 1.1e+06 1.1e+06 1.1e+06 ... 1.094e+06 1.094e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.334e+06 1.334e+06 1.334e+06 ... 1.34e+06 1.34e+06
#   * y            (y) float64 1.35e+06 1.35e+06 1.35e+06 ... 1.344e+06 1.344e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.304e+06 1.304e+06 1.304e+06 ... 1.31e+06 1.31e+06
#   * y            (y) float64 1.319e+06 1.319e+06 ... 1.313e+06 1.313e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.158e+06 1.158e+06 ... 1.164e+06 1.164e+06
#   * y            (y) float64 1.171e+06 1.171e+06 ... 1.165e+06 1.165e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.226e+06 1.226e+06 ... 1.232e+06 1.232e+06
#   * y            (y) float64 1.24e+06 1.24e+06 1.24e+06 ... 1.234e+06 1.234e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.298e+06 1.298e+06 ... 1.304e+06 1.304e+06
#   * y            (y) float64 1.313e+06 1.313e+06 ... 1.307e+06 1.307e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.174e+06 1.174e+06 1.174e+06 ... 1.18e+06 1.18e+06
#   * y            (y) float64 1.187e+06 1.187e+06 ... 1.181e+06 1.181e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.254e+06 1.254e+06 1.254e+06 ... 1.26e+06 1.26e+06
#   * y            (y) float64 1.269e+06 1.269e+06 ... 1.263e+06 1.263e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.152e+06 1.152e+06 ... 1.158e+06 1.158e+06
#   * y            (y) float64 1.164e+06 1.164e+06 ... 1.158e+06 1.158e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.08e+06 1.08e+06 1.08e+06 ... 1.086e+06 1.086e+06
#   * y            (y) float64 1.092e+06 1.092e+06 ... 1.086e+06 1.086e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.285e+06 1.285e+06 ... 1.291e+06 1.291e+06
#   * y            (y) float64 1.3e+06 1.3e+06 1.3e+06 ... 1.294e+06 1.294e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.28e+06 1.28e+06 1.28e+06 ... 1.286e+06 1.286e+06
#   * y            (y) float64 1.294e+06 1.294e+06 ... 1.288e+06 1.288e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.076e+06 1.077e+06 ... 1.082e+06 1.082e+06
#   * y            (y) float64 1.088e+06 1.088e+06 ... 1.082e+06 1.082e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.072e+06 1.072e+06 ... 1.078e+06 1.078e+06
#   * y            (y) float64 1.083e+06 1.083e+06 ... 1.077e+06 1.077e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.268e+06 1.268e+06 ... 1.274e+06 1.274e+06
#   * y            (y) float64 1.282e+06 1.282e+06 ... 1.276e+06 1.276e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.285e+06 1.285e+06 ... 1.291e+06 1.291e+06
#   * y            (y) float64 1.3e+06 1.3e+06 1.3e+06 ... 1.294e+06 1.294e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.021e+06 1.021e+06 ... 1.027e+06 1.027e+06
#   * y            (y) float64 1.032e+06 1.032e+06 ... 1.026e+06 1.026e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.126e+06 1.126e+06 ... 1.131e+06 1.132e+06
#   * y            (y) float64 1.137e+06 1.137e+06 ... 1.131e+06 1.131e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.129e+06 1.129e+06 ... 1.135e+06 1.135e+06
#   * y            (y) float64 1.141e+06 1.141e+06 ... 1.135e+06 1.135e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.278e+06 1.278e+06 ... 1.284e+06 1.284e+06
#   * y            (y) float64 1.293e+06 1.293e+06 ... 1.287e+06 1.287e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.023e+06 1.023e+06 ... 1.029e+06 1.029e+06
#   * y            (y) float64 1.033e+06 1.033e+06 ... 1.027e+06 1.027e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.208e+06 1.208e+06 ... 1.214e+06 1.214e+06
#   * y            (y) float64 1.222e+06 1.222e+06 ... 1.216e+06 1.216e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.065e+06 1.065e+06 ... 1.071e+06 1.071e+06
#   * y            (y) float64 1.076e+06 1.076e+06 1.076e+06 ... 1.07e+06 1.07e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.048e+06 1.049e+06 ... 1.054e+06 1.054e+06
#   * y            (y) float64 1.059e+06 1.059e+06 ... 1.053e+06 1.053e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.11e+06 1.11e+06 1.11e+06 ... 1.115e+06 1.116e+06
#   * y            (y) float64 1.121e+06 1.121e+06 ... 1.115e+06 1.115e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.281e+06 1.281e+06 ... 1.287e+06 1.287e+06
#   * y            (y) float64 1.296e+06 1.296e+06 1.296e+06 ... 1.29e+06 1.29e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.18e+06 1.18e+06 1.18e+06 ... 1.186e+06 1.186e+06
#   * y            (y) float64 1.193e+06 1.193e+06 ... 1.187e+06 1.187e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.034e+06 1.034e+06 ... 1.039e+06 1.04e+06
#   * y            (y) float64 1.044e+06 1.044e+06 ... 1.038e+06 1.038e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.132e+06 1.132e+06 ... 1.138e+06 1.138e+06
#   * y            (y) float64 1.144e+06 1.144e+06 ... 1.138e+06 1.138e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.234e+06 1.234e+06 1.234e+06 ... 1.24e+06 1.24e+06
#   * y            (y) float64 1.248e+06 1.248e+06 ... 1.242e+06 1.242e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.277e+06 1.277e+06 ... 1.283e+06 1.283e+06
#   * y            (y) float64 1.291e+06 1.291e+06 ... 1.285e+06 1.285e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.348e+06 1.348e+06 ... 1.354e+06 1.354e+06
#   * y            (y) float64 1.364e+06 1.364e+06 ... 1.358e+06 1.358e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.352e+06 1.352e+06 ... 1.358e+06 1.358e+06
#   * y            (y) float64 1.369e+06 1.368e+06 ... 1.363e+06 1.363e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.28e+06 1.28e+06 1.28e+06 ... 1.286e+06 1.286e+06
#   * y            (y) float64 1.295e+06 1.295e+06 ... 1.289e+06 1.289e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.442e+06 1.442e+06 ... 1.448e+06 1.448e+06
#   * y            (y) float64 1.46e+06 1.46e+06 1.46e+06 ... 1.455e+06 1.454e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.122e+06 1.122e+06 ... 1.128e+06 1.128e+06
#   * y            (y) float64 1.134e+06 1.134e+06 ... 1.128e+06 1.128e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.112e+06 1.112e+06 ... 1.118e+06 1.118e+06
#   * y            (y) float64 1.123e+06 1.123e+06 ... 1.117e+06 1.117e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.373e+06 1.373e+06 ... 1.379e+06 1.379e+06
#   * y            (y) float64 1.39e+06 1.39e+06 1.39e+06 ... 1.384e+06 1.384e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.283e+06 1.283e+06 ... 1.289e+06 1.289e+06
#   * y            (y) float64 1.298e+06 1.298e+06 ... 1.292e+06 1.292e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.265e+06 1.265e+06 ... 1.271e+06 1.271e+06
#   * y            (y) float64 1.28e+06 1.279e+06 ... 1.274e+06 1.274e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.074e+06 1.074e+06 1.074e+06 ... 1.08e+06 1.08e+06
#   * y            (y) float64 1.085e+06 1.085e+06 ... 1.079e+06 1.079e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.139e+06 1.139e+06 ... 1.145e+06 1.145e+06
#   * y            (y) float64 1.151e+06 1.151e+06 ... 1.145e+06 1.145e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.203e+06 1.203e+06 ... 1.209e+06 1.209e+06
#   * y            (y) float64 1.216e+06 1.216e+06 1.216e+06 ... 1.21e+06 1.21e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.199e+06 1.199e+06 ... 1.205e+06 1.205e+06
#   * y            (y) float64 1.212e+06 1.212e+06 ... 1.206e+06 1.206e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.191e+06 1.191e+06 ... 1.197e+06 1.197e+06
#   * y            (y) float64 1.204e+06 1.204e+06 ... 1.198e+06 1.198e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.285e+06 1.285e+06 ... 1.291e+06 1.291e+06
#   * y            (y) float64 1.3e+06 1.3e+06 1.3e+06 ... 1.294e+06 1.294e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.206e+06 1.206e+06 ... 1.212e+06 1.212e+06
#   * y            (y) float64 1.22e+06 1.22e+06 1.22e+06 ... 1.214e+06 1.214e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.105e+06 1.105e+06 ... 1.111e+06 1.111e+06
#   * y            (y) float64 1.116e+06 1.116e+06 1.116e+06 ... 1.11e+06 1.11e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.077e+06 1.077e+06 ... 1.083e+06 1.083e+06
#   * y            (y) float64 1.088e+06 1.088e+06 ... 1.082e+06 1.082e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.231e+06 1.231e+06 ... 1.237e+06 1.237e+06
#   * y            (y) float64 1.245e+06 1.245e+06 ... 1.239e+06 1.239e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.33e+06 1.33e+06 1.33e+06 ... 1.336e+06 1.336e+06
#   * y            (y) float64 1.345e+06 1.345e+06 ... 1.34e+06 1.339e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.142e+06 1.142e+06 ... 1.148e+06 1.148e+06
#   * y            (y) float64 1.154e+06 1.154e+06 ... 1.148e+06 1.148e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.206e+06 1.206e+06 ... 1.212e+06 1.212e+06
#   * y            (y) float64 1.219e+06 1.219e+06 ... 1.213e+06 1.213e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.094e+06 1.094e+06 1.094e+06 ... 1.1e+06 1.1e+06
#   * y            (y) float64 1.106e+06 1.106e+06 1.106e+06 ... 1.1e+06 1.1e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.073e+06 1.073e+06 ... 1.079e+06 1.079e+06
#   * y            (y) float64 1.084e+06 1.084e+06 ... 1.078e+06 1.078e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.074e+06 1.074e+06 1.075e+06 ... 1.08e+06 1.08e+06
#   * y            (y) float64 1.086e+06 1.086e+06 1.086e+06 ... 1.08e+06 1.08e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.084e+06 1.084e+06 1.084e+06 ... 1.09e+06 1.09e+06
#   * y            (y) float64 1.095e+06 1.095e+06 ... 1.089e+06 1.089e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.277e+06 1.277e+06 ... 1.283e+06 1.283e+06
#   * y            (y) float64 1.292e+06 1.292e+06 ... 1.286e+06 1.286e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.191e+06 1.191e+06 ... 1.197e+06 1.197e+06
#   * y            (y) float64 1.204e+06 1.204e+06 ... 1.198e+06 1.198e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.252e+06 1.252e+06 ... 1.258e+06 1.258e+06
#   * y            (y) float64 1.266e+06 1.266e+06 1.266e+06 ... 1.26e+06 1.26e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.274e+06 1.274e+06 1.274e+06 ... 1.28e+06 1.28e+06
#   * y            (y) float64 1.289e+06 1.289e+06 ... 1.283e+06 1.283e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.027e+06 1.028e+06 ... 1.033e+06 1.033e+06
#   * y            (y) float64 1.038e+06 1.038e+06 ... 1.032e+06 1.032e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.386e+06 1.386e+06 ... 1.392e+06 1.392e+06
#   * y            (y) float64 1.403e+06 1.403e+06 ... 1.397e+06 1.397e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.17e+06 1.17e+06 1.17e+06 ... 1.176e+06 1.176e+06
#   * y            (y) float64 1.183e+06 1.183e+06 ... 1.177e+06 1.177e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.106e+06 1.106e+06 ... 1.112e+06 1.112e+06
#   * y            (y) float64 1.118e+06 1.118e+06 ... 1.112e+06 1.112e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.081e+06 1.081e+06 ... 1.087e+06 1.087e+06
#   * y            (y) float64 1.092e+06 1.092e+06 ... 1.086e+06 1.086e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.163e+06 1.163e+06 ... 1.169e+06 1.169e+06
#   * y            (y) float64 1.175e+06 1.175e+06 ... 1.169e+06 1.169e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.282e+06 1.282e+06 ... 1.288e+06 1.288e+06
#   * y            (y) float64 1.297e+06 1.297e+06 ... 1.291e+06 1.291e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.17e+06 1.17e+06 1.17e+06 ... 1.176e+06 1.176e+06
#   * y            (y) float64 1.182e+06 1.182e+06 ... 1.176e+06 1.176e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.376e+06 1.376e+06 ... 1.382e+06 1.382e+06
#   * y            (y) float64 1.393e+06 1.393e+06 ... 1.387e+06 1.387e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.078e+06 1.079e+06 ... 1.084e+06 1.084e+06
#   * y            (y) float64 1.09e+06 1.09e+06 1.09e+06 ... 1.084e+06 1.084e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.319e+06 1.319e+06 ... 1.325e+06 1.325e+06
#   * y            (y) float64 1.335e+06 1.335e+06 ... 1.329e+06 1.329e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.072e+06 1.072e+06 ... 1.078e+06 1.078e+06
#   * y            (y) float64 1.083e+06 1.083e+06 ... 1.077e+06 1.077e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.156e+06 1.156e+06 ... 1.162e+06 1.162e+06
#   * y            (y) float64 1.168e+06 1.168e+06 ... 1.162e+06 1.162e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.099e+06 1.099e+06 ... 1.105e+06 1.105e+06
#   * y            (y) float64 1.111e+06 1.111e+06 ... 1.105e+06 1.105e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.251e+06 1.251e+06 ... 1.257e+06 1.257e+06
#   * y            (y) float64 1.265e+06 1.265e+06 ... 1.259e+06 1.259e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.277e+06 1.277e+06 ... 1.283e+06 1.283e+06
#   * y            (y) float64 1.292e+06 1.292e+06 ... 1.286e+06 1.286e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.434e+06 1.435e+06 1.435e+06 ... 1.44e+06 1.44e+06
#   * y            (y) float64 1.453e+06 1.453e+06 ... 1.447e+06 1.447e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.071e+06 1.071e+06 ... 1.077e+06 1.077e+06
#   * y            (y) float64 1.082e+06 1.082e+06 ... 1.076e+06 1.076e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.082e+06 1.082e+06 ... 1.088e+06 1.088e+06
#   * y            (y) float64 1.093e+06 1.093e+06 ... 1.087e+06 1.087e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.407e+06 1.407e+06 ... 1.413e+06 1.413e+06
#   * y            (y) float64 1.424e+06 1.424e+06 ... 1.418e+06 1.418e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.083e+06 1.083e+06 ... 1.089e+06 1.089e+06
#   * y            (y) float64 1.094e+06 1.094e+06 ... 1.088e+06 1.088e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.277e+06 1.277e+06 ... 1.283e+06 1.283e+06
#   * y            (y) float64 1.292e+06 1.292e+06 ... 1.286e+06 1.286e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.152e+06 1.152e+06 ... 1.158e+06 1.158e+06
#   * y            (y) float64 1.164e+06 1.164e+06 ... 1.158e+06 1.158e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.276e+06 1.276e+06 ... 1.282e+06 1.282e+06
#   * y            (y) float64 1.29e+06 1.29e+06 1.29e+06 ... 1.285e+06 1.284e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.279e+06 1.279e+06 ... 1.285e+06 1.285e+06
#   * y            (y) float64 1.293e+06 1.293e+06 ... 1.288e+06 1.287e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.096e+06 1.096e+06 ... 1.102e+06 1.102e+06
#   * y            (y) float64 1.108e+06 1.108e+06 ... 1.102e+06 1.102e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.167e+06 1.167e+06 ... 1.173e+06 1.173e+06
# ...
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.078e+06 1.078e+06 ... 1.084e+06 1.084e+06
#   * y            (y) float64 1.09e+06 1.09e+06 1.09e+06 ... 1.084e+06 1.084e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.277e+06 1.277e+06 ... 1.283e+06 1.283e+06
#   * y            (y) float64 1.291e+06 1.291e+06 ... 1.285e+06 1.285e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.237e+06 1.237e+06 ... 1.243e+06 1.243e+06
#   * y            (y) float64 1.251e+06 1.251e+06 ... 1.245e+06 1.245e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.438e+06 1.438e+06 ... 1.444e+06 1.444e+06
#   * y            (y) float64 1.456e+06 1.456e+06 1.456e+06 ... 1.45e+06 1.45e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.083e+06 1.083e+06 ... 1.089e+06 1.089e+06
#   * y            (y) float64 1.094e+06 1.094e+06 ... 1.088e+06 1.088e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.155e+06 1.155e+06 ... 1.161e+06 1.161e+06
#   * y            (y) float64 1.168e+06 1.168e+06 ... 1.162e+06 1.162e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.079e+06 1.079e+06 ... 1.085e+06 1.085e+06
#   * y            (y) float64 1.09e+06 1.09e+06 1.09e+06 ... 1.084e+06 1.084e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.034e+06 1.034e+06 1.034e+06 ... 1.04e+06 1.04e+06
#   * y            (y) float64 1.045e+06 1.045e+06 ... 1.039e+06 1.039e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.193e+06 1.193e+06 ... 1.199e+06 1.199e+06
#   * y            (y) float64 1.206e+06 1.206e+06 1.206e+06 ... 1.2e+06 1.2e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.281e+06 1.281e+06 ... 1.287e+06 1.287e+06
#   * y            (y) float64 1.296e+06 1.296e+06 1.296e+06 ... 1.29e+06 1.29e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.107e+06 1.107e+06 ... 1.113e+06 1.113e+06
#   * y            (y) float64 1.118e+06 1.118e+06 ... 1.112e+06 1.112e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.25e+06 1.25e+06 1.25e+06 ... 1.256e+06 1.256e+06
#   * y            (y) float64 1.264e+06 1.264e+06 ... 1.258e+06 1.258e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.277e+06 1.277e+06 ... 1.283e+06 1.283e+06
#   * y            (y) float64 1.292e+06 1.292e+06 ... 1.286e+06 1.286e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.322e+06 1.322e+06 ... 1.328e+06 1.328e+06
#   * y            (y) float64 1.338e+06 1.337e+06 ... 1.332e+06 1.332e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.303e+06 1.303e+06 ... 1.309e+06 1.309e+06
#   * y            (y) float64 1.318e+06 1.318e+06 ... 1.312e+06 1.312e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.282e+06 1.282e+06 ... 1.288e+06 1.288e+06
#   * y            (y) float64 1.297e+06 1.297e+06 ... 1.291e+06 1.291e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.079e+06 1.079e+06 ... 1.085e+06 1.085e+06
#   * y            (y) float64 1.091e+06 1.091e+06 ... 1.085e+06 1.085e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.162e+06 1.162e+06 ... 1.168e+06 1.168e+06
#   * y            (y) float64 1.175e+06 1.175e+06 ... 1.169e+06 1.169e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.24e+06 1.24e+06 1.24e+06 ... 1.246e+06 1.246e+06
#   * y            (y) float64 1.254e+06 1.254e+06 ... 1.248e+06 1.248e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.158e+06 1.158e+06 ... 1.164e+06 1.164e+06
#   * y            (y) float64 1.17e+06 1.17e+06 1.17e+06 ... 1.164e+06 1.164e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.24e+06 1.24e+06 1.24e+06 ... 1.246e+06 1.246e+06
#   * y            (y) float64 1.254e+06 1.254e+06 ... 1.248e+06 1.248e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.067e+06 1.067e+06 ... 1.073e+06 1.073e+06
#   * y            (y) float64 1.079e+06 1.078e+06 ... 1.073e+06 1.073e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.275e+06 1.275e+06 ... 1.281e+06 1.281e+06
#   * y            (y) float64 1.289e+06 1.289e+06 ... 1.283e+06 1.283e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.277e+06 1.277e+06 ... 1.283e+06 1.283e+06
#   * y            (y) float64 1.292e+06 1.292e+06 ... 1.286e+06 1.286e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.246e+06 1.246e+06 ... 1.252e+06 1.252e+06
#   * y            (y) float64 1.26e+06 1.26e+06 1.26e+06 ... 1.254e+06 1.254e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.124e+06 1.124e+06 1.124e+06 ... 1.13e+06 1.13e+06
#   * y            (y) float64 1.135e+06 1.135e+06 ... 1.13e+06 1.129e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.102e+06 1.102e+06 ... 1.108e+06 1.108e+06
#   * y            (y) float64 1.113e+06 1.113e+06 ... 1.107e+06 1.107e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.331e+06 1.331e+06 ... 1.337e+06 1.337e+06
#   * y            (y) float64 1.347e+06 1.347e+06 ... 1.341e+06 1.341e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.158e+06 1.159e+06 ... 1.164e+06 1.164e+06
#   * y            (y) float64 1.171e+06 1.171e+06 ... 1.165e+06 1.165e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.083e+06 1.083e+06 ... 1.089e+06 1.089e+06
#   * y            (y) float64 1.094e+06 1.094e+06 ... 1.088e+06 1.088e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.082e+06 1.082e+06 ... 1.088e+06 1.088e+06
#   * y            (y) float64 1.093e+06 1.093e+06 ... 1.087e+06 1.087e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.236e+06 1.236e+06 ... 1.242e+06 1.242e+06
#   * y            (y) float64 1.25e+06 1.25e+06 1.25e+06 ... 1.244e+06 1.244e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.073e+06 1.073e+06 ... 1.079e+06 1.079e+06
#   * y            (y) float64 1.084e+06 1.084e+06 ... 1.078e+06 1.078e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.079e+06 1.079e+06 ... 1.085e+06 1.085e+06
#   * y            (y) float64 1.09e+06 1.09e+06 1.09e+06 ... 1.084e+06 1.084e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
# <xarray.DataArray (band: 7, y: 201, x: 201)>
# [282807 values with dtype=float64]
# Coordinates:
#   * band         (band) int64 1 2 3 4 5 6 7
#   * x            (x) float64 1.103e+06 1.103e+06 ... 1.109e+06 1.109e+06
#   * y            (y) float64 1.115e+06 1.115e+06 ... 1.109e+06 1.109e+06
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0
#     long_name:      ('B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7')
