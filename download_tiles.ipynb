# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tqdm import tqdm
import ee
import pandas as pd
from shapely.geometry import Point,Polygon

# %%
try:
    ee.Initialize()
except Exception as e:
        ee.Authenticate()
        ee.Initialize()

# %%
# CONSTANT
CSV_PATH    = '../wealth_index.csv'
L8          = 'LANDSAT/LC08/C01/T1'
L7          = 'LANDSAT/LE07/C02/T1'
L5          = 'LANDSAT/LT05/C02/T1'
L8_BANDS    = ['B2','B3','B4','B5','B6','B7']
L7_BANDS    = ['B1','B2','B3','B4','B5','B7']
BAND_EQUIV  = ['BLUE','GREEN','RED','NIR','SWIR1','SWIR2']
BB_SIZE     = 0.05

# %%
csv = pd.read_csv(CSV_PATH)
csv.head()
# Out:
#   country  year  month  day  cluster        lat        lon  households  \
# 0  angola  2011    NaN  NaN        1 -12.350257  13.534922          36
# 1  angola  2011    NaN  NaN        2 -12.360865  13.551494          32
# 2  angola  2011    NaN  NaN        3 -12.613421  13.413085          36
# 3  angola  2011    NaN  NaN        4 -12.581454  13.397711          35
# 4  angola  2011    NaN  NaN        5 -12.578135  13.418748          37
#
#    wealthpooled
# 0      2.312757
# 1      2.010293
# 2      0.877744
# 3      1.066994
# 4      1.750153

# %%
# @Yeh, 2020 
def decode_qamask(img: ee.Image) -> ee.Image:
    '''
    Args
    - img: ee.Image, Landsat 5/7/8 image containing 'pixel_qa' band
    Returns
    - masks: ee.Image, contains 5 bands of masks
    Pixel QA Bit Flags (universal across Landsat 5/7/8)
    Bit  Attribute
    0    Fill
    1    Clear
    2    Water
    3    Cloud Shadow
    4    Snow
    5    Cloud
    '''
    qa = img.select('QA_PIXEL')
    clear = qa.bitwiseAnd(2).neq(0)  # 0 = not clear, 1 = clear
    clear = clear.updateMask(clear).rename(['pxqa_clear'])

    water = qa.bitwiseAnd(4).neq(0)  # 0 = not water, 1 = water
    water = water.updateMask(water).rename(['pxqa_water'])

    cloud_shadow = qa.bitwiseAnd(8).eq(0)  # 0 = shadow, 1 = not shadow
    cloud_shadow = cloud_shadow.updateMask(cloud_shadow).rename(['pxqa_cloudshadow'])

    snow = qa.bitwiseAnd(16).eq(0)  # 0 = snow, 1 = not snow
    snow = snow.updateMask(snow).rename(['pxqa_snow'])

    cloud = qa.bitwiseAnd(32).eq(0)  # 0 = cloud, 1 = not cloud
    cloud = cloud.updateMask(cloud).rename(['pxqa_cloud'])

    masks = ee.Image.cat([clear, water, cloud_shadow, snow, cloud])
    return masks


def mask_qaclear(img: ee.Image) -> ee.Image:
    '''
    Args
    - img: ee.Image
    Returns
    - img: ee.Image, input image with cloud-shadow, snow, cloud, and unclear
        pixels masked out
    '''
    qam = decode_qamask(img)
    cloudshadow_mask = qam.select('pxqa_cloudshadow')
    snow_mask = qam.select('pxqa_snow')
    cloud_mask = qam.select('pxqa_cloud')
    return img.updateMask(cloudshadow_mask).updateMask(snow_mask).updateMask(cloud_mask)

# %%
# def cloudMaskL457(image):
#     qa = image.select('pixel_qa') 
#     cloud1 = qa.bitwiseAnd(1<<5).eq(0)
#     cloud2 = qa.bitwiseAnd(1<<7).eq(0)
#     cloud3 = qa.bitwiseAnd(1<<3).eq(0)
#     mask2 = image.mask().reduce(ee.Reducer.min());
#     return image.updateMask(cloud1).updateMask(cloud2).updateMask(cloud3).updateMask(mask2).divide(10000).copyProperties(image, ["system:time_start"])

def fill_gaps(img : ee.Image) -> ee.Image:
    return img.focal_mean(1.5,'square','pixels',2).blend(img)

# %%
def merge_landsat_bands(year):
    l8 = l7 = l5 = None
    start_date = str(int(year)-1)+"-01-01"
    end_date = str(int(year)+1)+"-12-31"
    if year >= 2012:
        l8 = ee.ImageCollection(L8).filterDate(start_date, end_date).filterMetadata('CLOUD_COVER', 'less_than', '20')
        l8 = l8.map(mask_qaclear).select(L8_BANDS, BAND_EQUIV)
    if year >= 2000:
        l7 = ee.ImageCollection(L7).filterDate(start_date, end_date)
        l7 = l7.map(mask_qaclear)
        l7 = l7.select(L7_BANDS, BAND_EQUIV)        
        if l8 is not None:
             l8 = l8.merge(l7)
    if year <= 2011:
        l5 = ee.ImageCollection(L5).filterDate(start_date, end_date)
        l5 = l5.map(mask_qaclear).select(L7_BANDS, BAND_EQUIV)
        if l7 is not None:
            l7 = l5.merge(l7)
    if l8 is not None:
        return l8.median()
    if l7 is not None:
        return l7.median()
    return L5.median()

# %%
def bb_from_coords(lat, lon, margin=BB_SIZE/2):
    return Polygon([
        [lon-margin, lat-margin],
        [lon+margin, lat-margin],
        [lon+margin, lat+margin],
        [lon-margin, lat+margin],
        [lon-margin, lat-margin],
    ])

def ee_bb_from_coords(lat, lon, margin=BB_SIZE/2):
    return ee.Geometry.Polygon([
        [lon-margin, lat-margin],
        [lon+margin, lat-margin],
        [lon+margin, lat+margin],
        [lon-margin, lat+margin],
        [lon-margin, lat-margin],
    ])

def add_bb_to_csv(csv, margin=BB_SIZE/2):
    csv['region'] = csv.apply(lambda x: bb_from_coords(x.lat, x.lon, margin), axis=1)
    return csv

# %%
csv = add_bb_to_csv(csv)
csv.head()
# Out:
#   country  year  month  day  cluster        lat        lon  households  \
# 0  angola  2011    NaN  NaN        1 -12.350257  13.534922          36
# 1  angola  2011    NaN  NaN        2 -12.360865  13.551494          32
# 2  angola  2011    NaN  NaN        3 -12.613421  13.413085          36
# 3  angola  2011    NaN  NaN        4 -12.581454  13.397711          35
# 4  angola  2011    NaN  NaN        5 -12.578135  13.418748          37
#
#    wealthpooled                                             region
# 0      2.312757  POLYGON ((13.509921646118164 -12.3752569198608...
# 1      2.010293  POLYGON ((13.526493644714355 -12.3858646392822...
# 2      0.877744  POLYGON ((13.388084983825683 -12.6384214401245...
# 3      1.066994  POLYGON ((13.372710800170898 -12.6064542770385...
# 4      1.750153  POLYGON ((13.393747901916504 -12.6031345367431...

# %%
cpt_task = 0
for year in csv.year.unique():
    sub_csv = csv[ csv.year==year ]
    raw_image = merge_landsat_bands(int(year))
    for country in sub_csv.country.unique():
        if year == 2011 and country < "mozambique":
            continue
        print(country, year)
        sub_csv_ = sub_csv[ sub_csv.country==country ]
        for _,row in sub_csv_.iterrows():
            if cpt_task%1000==0:
                print(country, year)
            region = ee_bb_from_coords(row.lat, row.lon)
            image = raw_image.clip(region)
            name = str(row.lat)[:5].replace('.','_')+"_"+str(row.lon)[:5].replace('.','_')
            task = ee.batch.Export.image.toDrive(**{
                'image': image,
                'folder': 'landsat',
                'crs' : 'EPSG:3857',
                'fileNamePrefix' : name,
                'fileFormat': 'GeoTIFF',
                'scale': 30,
                'region': region
            })
            task.start()
            cpt_task+=1
# Out:
# mozambique 2011
# mozambique 2011
# uganda 2011
# uganda 2011
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/ee/data.py:329, in _execute_cloud_call(call, num_retries)
#     328 try:
# --> 329   return call.execute(num_retries=num_retries)
#     330 except googleapiclient.errors.HttpError as e:
#
# File ~/.local/lib/python3.10/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/googleapiclient/http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/image:export?alt=json returned "Too many tasks already in the queue (3000). Please wait for some of them to complete.". Details: "Too many tasks already in the queue (3000). Please wait for some of them to complete.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# Cell In[20], line 25
#      15 name = str(row.lat)[:5].replace('.','_')+"_"+str(row.lon)[:5].replace('.','_')
#      16 task = ee.batch.Export.image.toDrive(**{
#      17     'image': image,
#      18     'folder': 'landsat',
#    (...)
#      23     'region': region
#      24 })
# ---> 25 task.start()
#      26 cpt_task+=1
#
# File ~/.local/lib/python3.10/site-packages/ee/batch.py:90, in Task.start(self)
#      87   self.config['workloadTag'] = self.workload_tag
#      89 if self.task_type == Task.Type.EXPORT_IMAGE:
# ---> 90   result = data.exportImage(self._request_id, self.config)
#      91 elif self.task_type == Task.Type.EXPORT_MAP:
#      92   result = data.exportMap(self._request_id, self.config)
#
# File ~/.local/lib/python3.10/site-packages/ee/data.py:1479, in exportImage(request_id, params)
#    1458 """Starts an image export task running.
#    1459
#    1460 This is a low-level method. The higher-level ee.batch.Export.image object
#    (...)
#    1476   If you are using the cloud API, this will be an Operation.
#    1477 """
#    1478 params = params.copy()
# -> 1479 return _prepare_and_run_export(
#    1480     request_id, params,
#    1481     _get_cloud_api_resource().projects().image().export)
#
# File ~/.local/lib/python3.10/site-packages/ee/data.py:1594, in _prepare_and_run_export(request_id, params, export_endpoint)
#    1591   params['expression'] = serializer.encode(
#    1592       params['expression'], for_cloud_api=True)
#    1593 num_retries = MAX_RETRIES if request_id else 0
# -> 1594 return _execute_cloud_call(
#    1595     export_endpoint(project=_get_projects_path(), body=params),
#    1596     num_retries=num_retries)
#
# File ~/.local/lib/python3.10/site-packages/ee/data.py:331, in _execute_cloud_call(call, num_retries)
#     329   return call.execute(num_retries=num_retries)
#     330 except googleapiclient.errors.HttpError as e:
# --> 331   raise _translate_cloud_exception(e)
#
# EEException: Too many tasks already in the queue (3000). Please wait for some of them to complete.
